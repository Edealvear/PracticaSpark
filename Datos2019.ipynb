# %%
from pyspark import SparkContext, RDD
import json
import matplotlib.pyplot as plt

sc = SparkContext()
print("AAA")
# Out:
# 23/05/27 15:36:59 WARN Utils: Your hostname, lucia-VirtualBox resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 23/05/27 15:36:59 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/27 15:37:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# AAA

# %%
# !head -10 201906_Usage_Bicimad.json
# Out:
# { "_id" : { "$oid" : "5cf83b752f3843a016be4e2f" }, "user_day_code" : "e4d55deb9ac172a8d8f5f0a32599815bd51b7c8760d67e42b11adf7c0829341b", "idplug_base" : 21, "user_type" : 1, "idunplug_base" : 8, "travel_time" : 219, "idunplug_station" : 90, "ageRange" : 0, "idplug_station" : 66, "unplug_hourTime" : { "$date" : "2019-06-01T00:00:00.000+0200" }, "zip_code" : "" }
# { "_id" : { "$oid" : "5cf83b762f3843a016be4e48" }, "user_day_code" : "8a0c4123e924a50a958f51985eb71aea750fb072438035f149283490cc6bfaf4", "idplug_base" : 19, "user_type" : 1, "idunplug_base" : 19, "travel_time" : 359, "idunplug_station" : 71, "ageRange" : 4, "idplug_station" : 136, "unplug_hourTime" : { "$date" : "2019-06-01T00:00:00.000+0200" }, "zip_code" : "28039" }
# ...

# %%
rdd = sc.textFile("201906_Usage_Bicimad.json")
# Out:
# 23/05/27 17:34:01 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 165627 ms exceeds timeout 120000 ms
# 23/05/27 17:34:01 WARN SparkContext: Killing executors is not supported by current scheduler.
# 23/05/27 17:34:01 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# ...

# %%
def get_trayecto(line):
    data = json.loads(line)
    user = data['user_type']
    station1 = data['idunplug_station']
    station2 = data['idplug_station']
    #if user != 2 and user != 3:
    sol =[min(station1,station2),max(station1,station2)]
    #else:
        #sol = []
    return sol


rdd1 = rdd.map(get_trayecto)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[15], line 13
#       8     #else:
#       9         #sol = []
#      10     return sol
# ---> 13 rdd1 = rdd.map(get_trayecto)
#
# File ~/.local/lib/python3.10/site-packages/pyspark/rdd.py:745, in RDD.map(self, f, preservesPartitioning)
#     742 def func(_: int, iterator: Iterable[T]) -> Iterable[U]:
#     743     return map(fail_on_stopiteration(f), iterator)
# --> 745 return self.mapPartitionsWithIndex(func, preservesPartitioning)
#
# File ~/.local/lib/python3.10/site-packages/pyspark/rdd.py:871, in RDD.mapPartitionsWithIndex(self, f, preservesPartitioning)
#     832 def mapPartitionsWithIndex(
#     833     self: "RDD[T]",
#     834     f: Callable[[int, Iterable[T]], Iterable[U]],
#     835     preservesPartitioning: bool = False,
#     836 ) -> "RDD[U]":
#     837     """
# ...

# %%
def get_edad(line):
    data = json.loads(line)
    user = data['user_type']
    age = data['ageRange']
    
    if user != 2 and user != 3:
        sol =age
    else:
        sol = []
    return (sol)
rdd2 = rdd.map(get_edad)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[12], line 11
#       9         sol = []
#      10     return (sol)
# ---> 11 rdd2 = rdd.map(get_edad)
#
# File ~/.local/lib/python3.10/site-packages/pyspark/rdd.py:745, in RDD.map(self, f, preservesPartitioning)
#     742 def func(_: int, iterator: Iterable[T]) -> Iterable[U]:
#     743     return map(fail_on_stopiteration(f), iterator)
# --> 745 return self.mapPartitionsWithIndex(func, preservesPartitioning)
#
# File ~/.local/lib/python3.10/site-packages/pyspark/rdd.py:871, in RDD.mapPartitionsWithIndex(self, f, preservesPartitioning)
#     832 def mapPartitionsWithIndex(
#     833     self: "RDD[T]",
#     834     f: Callable[[int, Iterable[T]], Iterable[U]],
#     835     preservesPartitioning: bool = False,
#     836 ) -> "RDD[U]":
#     837     """
# ...
